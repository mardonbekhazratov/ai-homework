# %%
import tensorflow as tf

# %%
from tensorflow.keras.datasets import fashion_mnist

fmnist = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = fmnist

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
i = 1
plt.imshow(X_train[i], cmap='binary')
plt.title(class_names[y_train[i]])
plt.show()

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# First method: Sequential API

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, InputLayer

# %% [markdown]
# 1. Regression output faqat 1 ta neurondan iborat bo'ladi va hech qanday activation function ishlatilmaydi.
# 2. Classification, agar binary classification bo'lsa 1 ta neuron bo'ladi va sigmoid activation function ishlatiladi.
# 3. Classification, agar multiclass classification bo'lsa n ta neuron bo'ladi va softmax activation function ishlatiladi.

# %%
tf.random.set_seed(42)
model = Sequential([
    InputLayer(shape=[28, 28]),
    Flatten(name='flatten_layer'),
    Dense(300, activation='relu', name='hidden1'),
    Dense(100, activation='relu', name='hidden2'),
    Dense(10, activation='softmax', name='output')
])

# (N,784) -> (N, 300) -> (N, 100) -> (N, 10)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_layer (Flatten)         │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden1 (Dense)                 │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers[1]
# Out:
# <Dense name=hidden1, built=True>

# %%
weights, biases = model.get_layer('hidden1').get_weights()

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7851 - loss: 0.6098 - val_accuracy: 0.8555 - val_loss: 0.3958
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8637 - loss: 0.3714 - val_accuracy: 0.8583 - val_loss: 0.3800
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8768 - loss: 0.3310 - val_accuracy: 0.8610 - val_loss: 0.3763
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - accuracy: 0.8859 - loss: 0.3055 - val_accuracy: 0.8649 - val_loss: 0.3685
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.8921 - loss: 0.2855 - val_accuracy: 0.8711 - val_loss: 0.3531
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8973 - loss: 0.2694 - val_accuracy: 0.8689 - val_loss: 0.3559
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9029 - loss: 0.2547 - val_accuracy: 0.8749 - val_loss: 0.3535
# Epoch 8/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9070 - loss: 0.2422 - val_accuracy: 0.8736 - val_loss: 0.3539
# Epoch 9/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9119 - loss: 0.2303 - val_accuracy: 0.8700 - val_loss: 0.3678
# Epoch 10/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9160 - loss: 0.2209 - val_accuracy: 0.8722 - val_loss: 0.3634
# Epoch 11/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9181 - loss: 0.2139 - val_accuracy: 0.8756 - val_loss: 0.3692
# Epoch 12/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9205 - loss: 0.2036 - val_accuracy: 0.8716 - val_loss: 0.3811
# Epoch 13/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9250 - loss: 0.1931 - val_accuracy: 0.8793 - val_loss: 0.3848
# Epoch 14/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9271 - loss: 0.1902 - val_accuracy: 0.8783 - val_loss: 0.3862
# Epoch 15/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9301 - loss: 0.1839 - val_accuracy: 0.8778 - val_loss: 0.3878
# Epoch 16/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9339 - loss: 0.1728 - val_accuracy: 0.8819 - val_loss: 0.4039
# Epoch 17/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9367 - loss: 0.1648 - val_accuracy: 0.8780 - val_loss: 0.4307
# Epoch 18/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9352 - loss: 0.1658 - val_accuracy: 0.8818 - val_loss: 0.4130
# Epoch 19/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9413 - loss: 0.1558 - val_accuracy: 0.8818 - val_loss: 0.4356
# Epoch 20/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9413 - loss: 0.1520 - val_accuracy: 0.8853 - val_loss: 0.4450
# Epoch 21/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9419 - loss: 0.1482 - val_accuracy: 0.8827 - val_loss: 0.4665
# Epoch 22/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9426 - loss: 0.1484 - val_accuracy: 0.8794 - val_loss: 0.4843
# Epoch 23/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9465 - loss: 0.1390 - val_accuracy: 0.8797 - val_loss: 0.4942
# Epoch 24/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9471 - loss: 0.1385 - val_accuracy: 0.8791 - val_loss: 0.5334
# Epoch 25/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9489 - loss: 0.1335 - val_accuracy: 0.8865 - val_loss: 0.4698
# Epoch 26/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9490 - loss: 0.1294 - val_accuracy: 0.8783 - val_loss: 0.5261
# Epoch 27/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9482 - loss: 0.1331 - val_accuracy: 0.8757 - val_loss: 0.5239
# Epoch 28/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9502 - loss: 0.1258 - val_accuracy: 0.8824 - val_loss: 0.5558
# Epoch 29/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9519 - loss: 0.1248 - val_accuracy: 0.8836 - val_loss: 0.5710
# Epoch 30/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9544 - loss: 0.1154 - val_accuracy: 0.8819 - val_loss: 0.5882

# %%
import pandas as pd

pd.DataFrame(history.history).plot()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8803 - loss: 0.6172
# [0.5882384777069092, 0.8819000124931335]

# %%
y_pred = model.predict(X_test).argmax(axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_test
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, sample_weight= y_pred != y_test)
ConfusionMatrixDisplay(cm).plot()
plt.show()

# %%
y_pred == 6
# Out:
# array([9, 2, 1, ..., 8, 1, 5])

# %%
y_test == 0
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
X_wrong = X_test[(y_pred == 6) * (y_test == 0)]

# %%
print("Predicted:", class_names[6])
print("Actual:", class_names[0])
plt.imshow(X_wrong[1], cmap='binary')
plt.show()
# Out:
# Predicted: Shirt
# Actual: T-shirt/top
