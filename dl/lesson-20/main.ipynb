# %%
from transformers import pipeline

# %%
pipe = pipeline("text-generation", model="openai-community/gpt2")
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
print(pipe("Hey how are you", )[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Hey how are you?"
#
# He sighed. "I'm just wondering, about you. I've got to see you later, and you're not coming back."
#
# "I've been up all night to see you," she said.
#
# "I'm sure you'll be ready to go," he said.
#
# "You'd only have a few minutes before I leave."
#
# "How long?"
#
# "Two hours," she said.
#
# "So you'll be out there for five more?"
#
# "Two hours," she said.
#
# "You'll be home, when I'm ready to go."
#
# She shook her head. "You don't like having to go home?"
#
# "No, I don't want to. But if it's a good night's sleep, I'll be home. I mean, it really is a good night's sleep, right?"
#
# He nodded. "Good night."
#
# She rolled her eyes. "You're my friend?"
#
# He nodded. "No, I'm not. And I'll be back to work after that."
#
# "So you have a two-hour and a half drive to go?"
#
# "Twenty minutes."
#
# "Well

# %%
from transformers import AutoModelForCausalLM

# %%
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")
