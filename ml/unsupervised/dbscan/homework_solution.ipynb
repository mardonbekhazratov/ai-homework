# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

X, y = make_circles(n_samples=1000, factor=0.6, noise=0.05, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

nn = NearestNeighbors(n_neighbors=5)
nn.fit(X)
# Out:
# NearestNeighbors()

# %%
distances, indices = nn.kneighbors(X)

# %%
distances
# Out:
# array([[0.        , 0.00685121, 0.02230399, 0.02651   , 0.03533827],
#        [0.        , 0.02000256, 0.03142951, 0.03472573, 0.04351933],
#        [0.        , 0.00801159, 0.01837665, 0.02725331, 0.03280195],
#        ...,
#        [0.        , 0.01876039, 0.02760318, 0.02838696, 0.03043403],
#        [0.        , 0.02591675, 0.03871214, 0.04792911, 0.06756158],
#        [0.        , 0.022664  , 0.02898893, 0.0348368 , 0.05087372]],
#       shape=(1000, 5))

# %%
plt.plot(np.sort(distances.max(axis=1)))
plt.show()

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.1)
y_pred = dbscan.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
